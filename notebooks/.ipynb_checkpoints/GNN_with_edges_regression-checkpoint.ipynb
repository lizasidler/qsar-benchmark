# %%
# %load_ext autoreload
# %autoreload 2
    
import numpy as np
import torch
import matplotlib.pyplot as plt

from torch.utils.data import TensorDataset
from torch_geometric.loader import DataLoader
from torch_geometric.data import Data
from sklearn.model_selection import train_test_split

import gnn_edges
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
graphs_list = torch.load('../data_collection/graphs_with_edges.pt', weights_only=False)

graphs_train, graphs_val = train_test_split(
    graphs_list,
    test_size=0.10,
    random_state=42
)


train_loader = DataLoader(
    graphs_train, 
    batch_size=300,   
    shuffle=True
)

val_loader = DataLoader(
    graphs_val, 
    batch_size=300,   
    shuffle=True
)

device = torch.device("cpu")

# %%
epochs = 100
model = gnn_edges.GatedEdgeConv(128, 64, 1).to(device)
model.fit(train_loader, val_loader, device, epochs=epochs)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [07:21<00:00,  4.41s/it]

# %%
plt.plot(model.train_loss, label='train')
plt.plot(model.val_loss, label='val')

plt.legend()
plt.xticks(range(0, epochs, 10))
plt.savefig('nn_loss.png')
plt.show()

model.eval()
model.analysis(train_loader, val_loader, device)
# Out:
# R² Train Score: 0.867
# Train RMSE:     ±0.365
# Train MAE:      ±0.258
# R² Val Score: 0.637
# Val RMSE:     ±0.601
# Val MAE:      ±0.443

# %%
epochs = 100
model = gnn_edges.NNConv(256, 128, 16, 1).to(device)
model.fit(train_loader, val_loader, device, epochs=epochs)
# Out:
#   0%|                                                                                                                                                                             | 0/100 [00:47<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 3
#       1 epochs = 100
#       2 model = gnn_edges.NNConv(256, 128, 16, 1).to(device)
# ----> 3 model.fit(train_loader, val_loader, device, epochs=epochs)
#
# File ~/Documents/research/qsar-benchmark/notebooks/gnn_edges.py:75, in fit(self, train_loader, val_loader, device, epochs)
#      73 train_y = batch.y
#      74 loss = self.loss_fn(pred, train_y)
# ---> 75 loss.backward()
#      76 self.optimizer.step()
#      78 running_train_loss += loss.item() * batch.x.size(0)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)
#     623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
plt.plot(model.train_loss, label='train')
plt.plot(model.val_loss, label='val')

plt.legend()
plt.xticks(range(0, epochs, 10))
plt.savefig('nn_loss.png')
plt.show()

model.eval()
model.analysis(train_loader, val_loader, device)
